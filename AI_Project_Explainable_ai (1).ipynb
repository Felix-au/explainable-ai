# %% [markdown]
# # Explainable AI with Synthetic Data
#
# Demonstration on how a ML model, that was trained on real data, can be perfectly explored, reasoned around and validated in great detail with synthetic data. As synthetic data is not restricted by privacy, this allows to engage with far broader groups and communities, when it comes to algorithmic auditing, and ensuring the safety of developed ML-powered systems..

# %% [markdown]
# ## Train ML Model on Real Data
#
# Let's again use the UCI Adult [[1](#refs)] dataset, consisting of 48,842 records across 14 attributes. We will initially remove 4 attributes to make the analysis later on more insightful.

# %%
#!pip install scikit-learn seaborn lightgbm shap

# %%
import pandas as pd
import numpy as np

# fetch original data and drop a couple of variables
df = pd.read_csv('https://github.com/Felix-au/explainable-ai/blob/main/census.csv.gz')
df = df.drop(columns=['fnlwgt', 'education_num', 'race', 'native_country'])
df.head(5)
# Out:
#    age         workclass  education      marital_status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship     sex  capital_gain  capital_loss  hours_per_week income
# 0  Not-in-family    Male          2174             0              40  <=50K
# 1        Husband    Male             0             0              13  <=50K
# 2  Not-in-family    Male             0             0              40  <=50K
# 3        Husband    Male             0             0              40  <=50K
# 4           Wife  Female             0             0              40  <=50K

# %%
import lightgbm as lgb
from lightgbm import early_stopping
from sklearn.model_selection import train_test_split

target_col = 'income'
target_val = '>50K'

def prepare_xy(df):
    y = (df[target_col]==target_val).astype(int)
    str_cols = [col for col in df.select_dtypes(['object', 'string']).columns if col != target_col]
    for col in str_cols:
        df[col] = pd.Categorical(df[col])
    cat_cols = [col for col in df.select_dtypes('category').columns if col != target_col]
    num_cols = [col for col in df.select_dtypes('number').columns if col != target_col]
    for col in num_cols:
        df[col] = df[col].astype('float')
    X = df[cat_cols + num_cols]
    return X, y

def train_model(X, y):
    cat_cols = list(X.select_dtypes('category').columns)
    X_trn, X_val, y_trn, y_val = train_test_split(X, y, test_size=0.2, random_state=1)
    ds_trn = lgb.Dataset(X_trn, label=y_trn, categorical_feature=cat_cols, free_raw_data=False)
    ds_val = lgb.Dataset(X_val, label=y_val, categorical_feature=cat_cols, free_raw_data=False)
    model = lgb.train(
        params={
            'verbose': -1,
            'metric': 'auc',
            'objective': 'binary'
        },
        train_set=ds_trn,
        valid_sets=[ds_val],
        callbacks=[early_stopping(5)],
    )
    return model

import warnings
warnings.filterwarnings('ignore')

# %%
X, y = prepare_xy(df)
model = train_model(X, y)
# Out:
# Training until validation scores don't improve for 5 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.92857

# %% [markdown]
# ## Synthesize Data via MOSTLY AI
#
# The code below will automatically create a synthetic dataset using the Synthetic Data SDK.

# %%
# %pip install mostlyai[local]
# Out:
# Requirement already satisfied: mostlyai[local] in /usr/local/lib/python3.12/dist-packages (5.4.2)
# Requirement already satisfied: duckdb>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (1.3.2)
# Requirement already satisfied: environs>=9.5.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (14.4.0)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.2.4)
# Requirement already satisfied: gunicorn>=23.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.28.1)
# Requirement already satisfied: ipywidgets>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (8.1.7)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.2.2)
# Requirement already satisfied: pathvalidate>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.3.1)
# Requirement already satisfied: psutil>=5.9.5 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (5.9.5)
# Requirement already satisfied: pyarrow>=16.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (18.1.0)
# Requirement already satisfied: pycryptodomex>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.23.0)
# Requirement already satisfied: pydantic<3,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.11.10)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.32.4)
# Requirement already satisfied: rich>=13.7.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (13.9.4)
# Requirement already satisfied: schema>=0.7.5 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.7.8)
# Requirement already satisfied: semantic-version>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.10.0)
# Requirement already satisfied: smart-open>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (7.4.1)
# Requirement already satisfied: sqlparse>=0.5.3 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.5.3)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.20.0)
# Requirement already satisfied: xxhash>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.6.0)
# Requirement already satisfied: adlfs>=2023.4.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2025.8.0)
# Requirement already satisfied: azure-storage-blob>=12.16.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (12.27.1)
# Requirement already satisfied: cloudpathlib>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (0.23.0)
# Requirement already satisfied: fastapi<0.116,>=0.115.6 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.115.14)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.20.0)
# Requirement already satisfied: gcsfs>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2025.3.0)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (1.5.2)
# Requirement already satisfied: mostlyai-engine==1.6.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (1.6.1)
# Requirement already satisfied: mostlyai-qa==1.9.8 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (1.9.8)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.5)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.1.5)
# Requirement already satisfied: python-multipart>=0.0.20 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.0.20)
# Requirement already satisfied: s3fs>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2025.3.0)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.0.44)
# Requirement already satisfied: sshtunnel<0.5,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.4.0)
# Requirement already satisfied: torch<2.8.1,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.8.0+cu126)
# Requirement already satisfied: torchaudio<2.8.1,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (2.8.0+cu126)
# Requirement already satisfied: torchvision<0.23.1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.23.0+cu126)
# Requirement already satisfied: uvicorn<0.35,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (0.34.3)
# Requirement already satisfied: xlsxwriter<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mostlyai[local]) (3.2.9)
# Requirement already satisfied: accelerate>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (1.11.0)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (4.0.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub[hf-xet]>=0.30.2->mostlyai-engine==1.6.1->mostlyai[local]) (0.36.0)
# Requirement already satisfied: json-repair>=0.47.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (0.52.3)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (2.0.2)
# Requirement already satisfied: opacus>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (1.5.4)
# Requirement already satisfied: peft>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (0.17.1)
# Requirement already satisfied: setuptools>=77.0.3 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (80.9.0)
# Requirement already satisfied: tokenizers>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (0.22.1)
# Requirement already satisfied: transformers>=4.55.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (4.57.1)
# Requirement already satisfied: xgrammar>=0.1.21 in /usr/local/lib/python3.12/dist-packages (from mostlyai-engine==1.6.1->mostlyai[local]) (0.1.26)
# Requirement already satisfied: jinja2>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (3.1.6)
# Requirement already satisfied: model2vec>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (0.7.0)
# Requirement already satisfied: phik>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (0.12.5)
# Requirement already satisfied: plotly>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (6.3.1)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (1.6.1)
# Requirement already satisfied: scipy<1.16.0,>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from mostlyai-qa==1.9.8->mostlyai[local]) (1.15.3)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.12/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (1.36.0)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in /usr/local/lib/python3.12/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (0.0.53)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.12/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (1.25.1)
# Requirement already satisfied: fsspec>=2023.12.0 in /usr/local/lib/python3.12/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (2025.3.0)
# Requirement already satisfied: aiohttp>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (3.13.1)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (0.7.2)
# Requirement already satisfied: azure-storage-file-datalake>=12 in /usr/local/lib/python3.12/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (12.22.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.19.0)
# Requirement already satisfied: boto3>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.40.61)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from environs>=9.5.0->mostlyai[local]) (1.2.1)
# Requirement already satisfied: marshmallow>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from environs>=9.5.0->mostlyai[local]) (4.0.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<0.116,>=0.115.6->mostlyai[local]) (0.46.2)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gunicorn>=23.0.0->mostlyai[local]) (25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->mostlyai[local]) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->mostlyai[local]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->mostlyai[local]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->mostlyai[local]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.0->mostlyai[local]) (0.16.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (3.0.15)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.5->mostlyai[local]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->mostlyai[local]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->mostlyai[local]) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.0->mostlyai[local]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.0->mostlyai[local]) (2.19.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2023.1.0->mostlyai[local]) (2.25.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=6.0.0->mostlyai[local]) (1.17.3)
# Requirement already satisfied: azure-common in /usr/local/lib/python3.12/dist-packages (from smart-open[azure,gcs,s3]>=6.3.0; extra == "local"->mostlyai[local]) (1.1.28)
# Requirement already satisfied: paramiko>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from sshtunnel<0.5,>=0.4.0->mostlyai[local]) (4.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (1.13.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.8.1,>=2.8.0->mostlyai[local]) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision<0.23.1,>=0.23.0->mostlyai[local]) (11.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->mostlyai[local]) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->mostlyai[local]) (1.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.5.0->mostlyai-engine==1.6.1->mostlyai[local]) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.5.0->mostlyai-engine==1.6.1->mostlyai[local]) (0.6.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (0.12.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (1.40.61)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (6.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.22.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (2.0.0)
# Requirement already satisfied: msal<2,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (1.34.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.34.0->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (0.14.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.6.1->mostlyai[local]) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.6.1->mostlyai[local]) (4.67.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.6.1->mostlyai[local]) (0.70.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (4.9.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.28.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.7.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->huggingface-hub[hf-xet]>=0.30.2->mostlyai-engine==1.6.1->mostlyai[local]) (1.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.5->mostlyai-qa==1.9.8->mostlyai[local]) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.0->mostlyai[local]) (0.1.2)
# Requirement already satisfied: opt-einsum>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from opacus>=1.5.4->mostlyai-engine==1.6.1->mostlyai[local]) (3.4.0)
# Requirement already satisfied: bcrypt>=3.2 in /usr/local/lib/python3.12/dist-packages (from paramiko>=2.7.2->sshtunnel<0.5,>=0.4.0->mostlyai[local]) (5.0.0)
# Requirement already satisfied: invoke>=2.0 in /usr/local/lib/python3.12/dist-packages (from paramiko>=2.7.2->sshtunnel<0.5,>=0.4.0->mostlyai[local]) (2.2.1)
# Requirement already satisfied: pynacl>=1.5 in /usr/local/lib/python3.12/dist-packages (from paramiko>=2.7.2->sshtunnel<0.5,>=0.4.0->mostlyai[local]) (1.6.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (3.10.0)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly>=6.0.0->mostlyai-qa==1.9.8->mostlyai[local]) (2.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->mostlyai[local]) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->mostlyai-qa==1.9.8->mostlyai[local]) (3.6.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.0->mostlyai[local]) (1.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.8.1,>=2.8.0->mostlyai[local]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.0->mostlyai-engine==1.6.1->mostlyai[local]) (2024.11.6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from xgrammar>=0.1.21->mostlyai-engine==1.6.1->mostlyai[local]) (1.13.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from azure-identity->adlfs>=2023.4.0->mostlyai[local]) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs>=2023.1.0->mostlyai[local]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (2.23)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.71.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.26.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.8.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.8->mostlyai[local]) (3.2.5)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (2.10.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.2.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.1.0->mostlyai[local]) (3.3.1)

# %%
from mostlyai.sdk import MostlyAI

# initialize SDK
mostly = MostlyAI(local=True)  # or: MostlyAI(local=False, api_key='xxx')
# Out:
# Initializing Synthetic Data SDK 5.4.2 in LOCAL mode 🏠
# Connected to ]8;id=645449;file:///root/mostlyai\/root/]8;;\]8;id=420009;file:///root/mostlyai\mostlyai]8;;\ with 13 GB RAM, 2 CPUs, 0 GPUs available

# %%
# train a generator on the original training data
g = mostly.train(config={
    'name': 'Explainable AI Tutorial Census',
    'tables': [{
        'name': 'data',
        'data': df,
        'tabular_model_configuration': {'max_training_time': 1},
    }]
})
# Out:
# Created generator c7c1d782-dc3a-4edb-8b86-d88c604c9a5e
# Started generator training
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 🎉 Your generator is ready! Use it to create synthetic data. Publish it so others can do the same.

# %%
# generate a synthetic dataset
syn = mostly.generate(g).data()
print(f"Created synthetic data with {syn.shape[0]:,} records and {syn.shape[1]:,} attributes")
# Out:
# Created synthetic dataset c9e9ff38-85a4-4b4c-abcf-10dcf1cc6947 with generator c7c1d782-dc3a-4edb-8b86-d88c604c9a5e
# Started synthetic dataset generation
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 🎉 Your synthetic dataset is ready! Use it to consume the generated data. Publish it so others can do the same.
# Created synthetic data with 48,842 records and 11 attributes

# %% [markdown]
# ## Evaluate ML Performance on Synthetic
#
# This is also known as a Train-Real-Test-Synthetic (TRTS) approach.

# %%
from sklearn.metrics import roc_auc_score, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72

X_syn, y_syn = prepare_xy(syn)
p_syn = model.predict(X_syn)
auc = roc_auc_score(y_syn, p_syn)
acc = accuracy_score(y_syn, (p_syn >= 0.5).astype(int))
probs_df = pd.concat([
    pd.Series(p_syn, name='probability').reset_index(drop=True),
    pd.Series(y_syn, name=target_col).reset_index(drop=True),
], axis=1)
fig = sns.displot(data=probs_df, x='probability', hue=target_col, bins=20, multiple="stack")
fig = plt.title(f"Accuracy: {acc:.1%}, AUC: {auc:.1%}", fontsize=20)
plt.show()

# %% [markdown]
# ## Explain ML Model with Synthetic
#
# We will be using the **SHAP library**, a state-of-the-art Python package for Explainable AI. Learn more about SHAP and XAI at https://shap-lrjball.readthedocs.io/ and https://christophm.github.io/interpretable-ml-book/.

# %% [markdown]
# ### Calculate SHAP values for trained model w/ synthetic data
#
# Important: For this step no access to the original (privacy-sensitive) training data is needed anymore. We only need access to the trained model for inference, as well as to representative synthetic data.

# %%
import shap
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_syn)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### SHAP Feature Importance

# %%
shap.initjs()
shap.summary_plot(shap_values, X_syn, plot_size=0.2, plot_type='bar')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# ### SHAP Dependency Plots
#
# Let's study the value-dependent impact of each model feature. SHAP dependency plots are a great way to do so, as they not only show the average lift, but also the level of variance of that lift, at the same time.

# %%
def plot_shap_dependency(col):
    col_idx = [i for i in range(X_syn.shape[1]) if X_syn.columns[i] == col][0]
    # Check if shap_values is 1-dimensional
    if len(shap_values.shape) == 1:
        shp_vals = pd.Series(shap_values, name='shap_value')
    else:
        shp_vals = pd.Series(shap_values[:, col_idx], name='shap_value')

    col_vals = X_syn.iloc[:, col_idx].reset_index(drop=True)
    df = pd.concat([shp_vals, col_vals], axis=1)

    if col_vals.dtype.name != 'category':
        q01 = df[col].quantile(0.01)
        q99 = df[col].quantile(0.99)
        df = df.loc[(df[col] >= q01) & (df[col] <= q99), :]
    else:
        sorted_cats = list(df.groupby(col)['shap_value'].mean().sort_values().index)
        df[col] = df[col].cat.reorder_categories(sorted_cats, ordered=True)

    fig, ax = plt.subplots(figsize=(8, 4))
    plt.ylim(-3.2, 3.2)
    plt.title(col)
    plt.xlabel('')
    if col_vals.dtype.name == 'category':
        plt.xticks(rotation=90)
    ax.tick_params(axis='both', which='major', labelsize=8)
    ax.tick_params(axis='both', which='minor', labelsize=6)
    sns.lineplot(x=df[col], y=df['shap_value'], color='black').axhline(0, color='gray', alpha=1, lw=0.5)
    sns.scatterplot(x=df[col], y=df['shap_value'], alpha=0.1)

# %%
plot_shap_dependency('age')

# %%
plot_shap_dependency('marital_status')

# %%
plot_shap_dependency('hours_per_week')

# %% [markdown]
# ### SHAP Values for Single (Synthetic) Samples
#
# Let's study the factors behind the model scores by inspecting individual samples. Note, that this level of reasoning at an individual-level would not be possible with real data, if that consists of privacy-sensitive information. However, synthetic data allows to reason around samples at any scale.

# %%
def show_idx(i):
    shap.initjs()
    df = X_syn.iloc[i:i+1, :]
    df.insert(0, 'actual', y_syn.iloc[i])
    df.insert(1, 'score', p_syn[i])
    display(df)

    # Determine the correct expected value and shap values based on the structure of explainer.expected_value
    if isinstance(explainer.expected_value, np.ndarray) and explainer.expected_value.ndim > 0:
        # For multi-class classifiers
        expected_value = explainer.expected_value[1]
        shap_val = shap_values[1][i] if isinstance(shap_values[1], np.ndarray) else shap_values[1]
    else:
        # For binary classifiers or regressors
        expected_value = explainer.expected_value
        shap_val = shap_values[i]

    return shap.force_plot(expected_value, shap_val, X_syn.iloc[i, :], link="logit")

# %% [markdown]
# #### Random Sample

# %%
rnd_idx = X_syn.sample().index[0]
show_idx(rnd_idx)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
#        actual     score workclass education marital_status         occupation  \
# 21482       0  0.007586   Private      11th       Divorced  Machine-op-inspct
#
#         relationship   sex   age  capital_gain  capital_loss  hours_per_week
# 21482  Not-in-family  Male  33.0           0.0           0.0            40.0
# <div id='iZICY5RT2GCQ08A1EMA11'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "outValue": -4.873799842434291, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "features": {"0": {"effect": -0.011262992561661331, "value": "Private"}, "1": {"effect": -0.723332920802425, "value": "11th"}, "2": {"effect": -0.6847123463898023, "value": "Divorced"}, "3": {"effect": -0.5245834934121785, "value": "Machine-op-inspct"}, "4": {"effect": -0.2555587609334077, "value": "Not-in-family"}, "5": {"effect": 0.046114821369964136, "value": "Male"}, "6": {"effect": 0.0750087023712488, "value": 33.0}, "7": {"effect": -0.30086591806081403, "value": 0.0}, "8": {"effect": -0.03691800306676084, "value": 0.0}, "9": {"effect": -0.12411687882008997, "value": 40.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZICY5RT2GCQ08A1EMA11')
#   );
# </script>

# %% [markdown]
# #### Sample with lowest score

# %%
idx = np.argsort(p_syn)[0]
show_idx(idx)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
#       actual     score workclass education marital_status     occupation  \
# 6625       0  0.000156   Private      11th  Never-married  Other-service
#
#      relationship     sex   age  capital_gain  capital_loss  hours_per_week
# 6625    Own-child  Female  17.0         600.0           0.0             3.0
# <div id='iK6KQTITFAREAVOM1XWOC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "outValue": -8.768208341861516, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "features": {"0": {"effect": 0.0033832262366845366, "value": "Private"}, "1": {"effect": -0.5113481484127391, "value": "11th"}, "2": {"effect": -0.6912294060201543, "value": "Never-married"}, "3": {"effect": -0.4459065268529032, "value": "Other-service"}, "4": {"effect": -0.38176378378528647, "value": "Own-child"}, "5": {"effect": -0.1158735628594725, "value": "Female"}, "6": {"effect": -2.3797543782197708, "value": 17.0}, "7": {"effect": -1.2053723955050495, "value": 600.0}, "8": {"effect": -0.041559290801534345, "value": 0.0}, "9": {"effect": -0.6652120235129266, "value": 3.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iK6KQTITFAREAVOM1XWOC')
#   );
# </script>

# %% [markdown]
# #### Sample with highest score

# %%
idx = np.argsort(p_syn)[-1]
show_idx(idx)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
#        actual     score     workclass  education marital_status  \
# 30484       1  0.999766  Self-emp-inc  Assoc-voc       Divorced
#
#               occupation   relationship   sex   age  capital_gain  \
# 30484  Machine-op-inspct  Not-in-family  Male  31.0       14059.0
#
#        capital_loss  hours_per_week
# 30484        1565.0            40.0
# <div id='iD4GPZO6VEMGWPYGS8A7G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "outValue": 8.358141175285999, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "features": {"0": {"effect": -0.03985900111373322, "value": "Self-emp-inc"}, "1": {"effect": 0.2646541709522029, "value": "Assoc-voc"}, "2": {"effect": -0.28837174083311046, "value": "Divorced"}, "3": {"effect": -0.22953041165498267, "value": "Machine-op-inspct"}, "4": {"effect": -0.1067036957216275, "value": "Not-in-family"}, "5": {"effect": 0.05497901360546292, "value": "Male"}, "6": {"effect": 0.6774266205391565, "value": 31.0}, "7": {"effect": 9.011310278711411, "value": 14059.0}, "8": {"effect": 1.3676423475283876, "value": 1565.0}, "9": {"effect": -0.019834354598804334, "value": 40.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iD4GPZO6VEMGWPYGS8A7G')
#   );
# </script>

# %% [markdown]
# #### Sample with a median score

# %%
idx = np.argsort(p_syn)[int(len(p_syn)/2)]
show_idx(idx)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
#      actual     score workclass education marital_status        occupation  \
# 240       0  0.073185   Private   HS-grad       Divorced  Transport-moving
#
#     relationship   sex   age  capital_gain  capital_loss  hours_per_week
# 240    Unmarried  Male  56.0           0.0           0.0            40.0
# <div id='i8RZAEB7H7RIWC57B3GVX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "outValue": -2.5387596560956656, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "features": {"0": {"effect": 0.019550066338462346, "value": "Private"}, "1": {"effect": -0.3042948500654708, "value": "HS-grad"}, "2": {"effect": -0.5177539636314064, "value": "Divorced"}, "3": {"effect": 0.2444977099818673, "value": "Transport-moving"}, "4": {"effect": -0.6199295468311594, "value": "Unmarried"}, "5": {"effect": 0.20557053755066707, "value": "Male"}, "6": {"effect": 1.1076514168130103, "value": 56.0}, "7": {"effect": -0.25236646518199035, "value": 0.0}, "8": {"effect": -0.031208909653493433, "value": 0.0}, "9": {"effect": -0.05690359928778744, "value": 40.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i8RZAEB7H7RIWC57B3GVX')
#   );
# </script>

# %% [markdown]
# #### Sample a young Female Doctor

# %%
idx = syn[(syn.education=='Doctorate') & (syn.sex=='Female') & (syn.age<=30)].sample().index[0]
show_idx(idx)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
#        actual     score workclass  education marital_status      occupation  \
# 33735       0  0.027785   Private  Doctorate  Never-married  Prof-specialty
#
#         relationship     sex   age  capital_gain  capital_loss  hours_per_week
# 33735  Not-in-family  Female  28.0           0.0           0.0            30.0
# <div id='iMP76I9SYG5ZYJV6HKA0C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "outValue": -3.555093679123181, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "features": {"0": {"effect": 0.02427545129675899, "value": "Private"}, "1": {"effect": 1.270131498535641, "value": "Doctorate"}, "2": {"effect": -0.953290029694754, "value": "Never-married"}, "3": {"effect": 0.559619703186395, "value": "Prof-specialty"}, "4": {"effect": -0.37738231402870365, "value": "Not-in-family"}, "5": {"effect": -0.0764066727765676, "value": "Female"}, "6": {"effect": -0.4623373617878538, "value": 28.0}, "7": {"effect": -0.3151655369621553, "value": 0.0}, "8": {"effect": -0.06278781510019353, "value": 0.0}, "9": {"effect": -0.8281785496633836, "value": 30.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMP76I9SYG5ZYJV6HKA0C')
#   );
# </script>

# %% [markdown]
# ### Explore SHAP Values across a thousand samples

# %%
shap.initjs()

# Determine the correct expected value
if isinstance(explainer.expected_value, np.ndarray):
    expected_value = explainer.expected_value[1]
else:
    expected_value = explainer.expected_value

# Adjust how you access shap_values based on its structure
if isinstance(shap_values, list) and len(shap_values) > 1:
    shap_vals_subset = shap_values[1][:1000, :]
else:
    shap_vals_subset = shap_values[:1000, :]

shap.force_plot(expected_value, shap_vals_subset, X.iloc[:1000, :], link="logit")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# <div id='iUOHCC6QHEHNVJYCT663U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": -2.3335720521283645, "link": "logit", "featureNames": ["workclass", "education", "marital_status", "occupation", "relationship", "sex", "age", "capital_gain", "capital_loss", "hours_per_week"], "explanations": [{"outValue": -0.7466277091552713, "simIndex": 723.0, "features": {"0": {"effect": 0.011359376877891443, "value": "State-gov"}, "1": {"effect": 0.06216373859659053, "value": "Bachelors"}, "2": {"effect": 0.9856796743202269, "value": "Never-married"}, "3": {"effect": -0.5439430860636592, "value": "Adm-clerical"}, "4": {"effect": 0.6191181873239443, "value": "Not-in-family"}, "5": {"effect": 0.0458387082713842, "value": "Male"}, "6": {"effect": 0.8155048195852677, "value": 39.0}, "7": {"effect": -0.30794412486769973, "value": 2174.0}, "8": {"effect": -0.07088775002427522, "value": 0.0}, "9": {"effect": -0.029945201046577774, "value": 40.0}}}, {"outValue": -1.1170163142292995, "simIndex": 320.0, "features": {"0": {"effect": 0.1293499590408234, "value": "Self-emp-not-inc"}, "1": {"effect": -0.07170888034675263, "value": "Bachelors"}, "2": {"effect": -0.5536446794569365, "value": "Married-civ-spouse"}, "3": {"effect": 0.7001747602005661, "value": "Exec-managerial"}, "4": {"effect": -0.3636181374665233, "value": "Husband"}, "5": {"effect": 0.1737373607184343, "value": "Male"}, "6": {"effect": 0.9340747158486388, "value": 50.0}, "7": {"effect": -0.23664636790594876, "value": 0.0}, "8": {"effect": -0.034774874625941775, "value": 0.0}, "9": {"effect": 0.5396118818927054, "value": 13.0}}}, {"outValue": -4.510089532314877, "simIndex": 283.0, "features": {"0": {"effect": -0.04326906766163956, "value": "Private"}, "1": {"effect": -0.45805142526222165, "value": "HS-grad"}, "2": {"effect": -0.6994641025016517, "value": "Divorced"}, "3": {"effect": -0.9004482174754962, "value": "Handlers-cleaners"}, "4": {"effect": -0.6609458443783993, "value": "Not-in-family"}, "5": {"effect": 0.0721094746337405, "value": "Male"}, "6": {"effect": 0.8222470292306315, "value": 38.0}, "7": {"effect": -0.23625968605709657, "value": 0.0}, "8": {"effect": -0.039415482869275174, "value": 0.0}, "9": {"effect": -0.03302015784510409, "value": 40.0}}}, {"outValue": -0.8432555275295137, "simIndex": 743.0, "features": {"0": {"effect": 0.019227290433743986, "value": "Private"}, "1": {"effect": -0.27266357643739525, "value": "11th"}, "2": {"effect": 0.9628776411475055, "value": "Married-civ-spouse"}, "3": {"effect": -0.049686512296446314, "value": "Handlers-cleaners"}, "4": {"effect": 0.5905103714500067, "value": "Husband"}, "5": {"effect": 0.04953167812899397, "value": "Male"}, "6": {"effect": 0.5410444635460016, "value": 53.0}, "7": {"effect": -0.30419862486399385, "value": 0.0}, "8": {"effect": -0.06620009484233522, "value": 0.0}, "9": {"effect": 0.019873888332769457, "value": 40.0}}}, {"outValue": -0.34208586170211763, "simIndex": 832.0, "features": {"0": {"effect": 0.050352565729589835, "value": "Private"}, "1": {"effect": -0.4149265517593153, "value": "Bachelors"}, "2": {"effect": 0.8680513324056925, "value": "Married-civ-spouse"}, "3": {"effect": 0.7686436396809758, "value": "Prof-specialty"}, "4": {"effect": 0.6488874575488126, "value": "Wife"}, "5": {"effect": 0.05456121642558312, "value": "Female"}, "6": {"effect": 0.3778384733114422, "value": 28.0}, "7": {"effect": -0.31046194192943677, "value": 0.0}, "8": {"effect": -0.07741764475040144, "value": 0.0}, "9": {"effect": 0.02595764376330413, "value": 40.0}}}, {"outValue": 1.215878286920164, "simIndex": 963.0, "features": {"0": {"effect": 0.05802978330395927, "value": "Private"}, "1": {"effect": 0.6501255047905015, "value": "Masters"}, "2": {"effect": 0.7672294894391102, "value": "Married-civ-spouse"}, "3": {"effect": 0.5446359265657678, "value": "Exec-managerial"}, "4": {"effect": 0.6735094575562482, "value": "Wife"}, "5": {"effect": 0.052790770169822365, "value": "Female"}, "6": {"effect": 0.767187078552505,  ...

# %% [markdown]
# ## References<a class="anchor" name="refs"></a>
#
# 1. https://archive.ics.uci.edu/ml/datasets/adult
